# %%
# !pip install tensorflow
# !pip install tf-keras
# !pip install tensorflow-cpu
# !pip install tensorflow_probability

# %%
import tensorflow as ft
import tensorflow_probability as tfp
# Out:
# 2026-01-14 18:23:42.125400: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-14 18:23:42.257914: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-01-14 18:23:43.426589: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /media/gabriel-oduori/SERVER/dev_space/uncertainty_quantification_venv/lib/python3.13/site-packages/keras/src/export/tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
python3 -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"

# %%
tfd = tfp.distributions
tfpl  = tfp.layers


# initialize a normal distribution with mean 1000 and SD 15

normal = tfd.Normal(loc=100, scale=15)

normal
# Out:
# <tfp.distributions.Normal 'Normal' batch_shape=[] event_shape=[] dtype=float32>

# %%
normal_batched = tfd.Normal(loc=[100,200], scale=15)

normal_batched

# check mean

normal_batched.mean()
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([100., 200.], dtype=float32)>
